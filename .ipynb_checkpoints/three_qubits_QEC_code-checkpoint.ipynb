# %% [markdown]
# # Quantum Error Correction Project
# ## Philippe Noël, Alaisha Sharma, Nicolas Weninger
# ### 1. 3-qubit scheme

# %%
import os
import sys

from qiskit import QuantumProgram
import Qconfig
from qiskit.tools.visualization import plot_histogram

assert sys.version_info >= (3,5), "Only Python 3.5 or greater supported."

from qiskit.tools.visualization import plot_histogram, plot_state

import numpy as np
import matplotlib.pyplot as plt
from qutip import *
from IPython.display import Image

# %%
# Run circuit without any errors on local quantum simulator
qp1 = QuantumProgram()

# 3 qubits plus 2 ancillary qubits
n = 5

# Quantum register
q = qp1.create_quantum_register("q", n)
# Classical register
c = qp1.create_classical_register("c", n) 

# SimControl3 circuit
sim_control3 = qp1.create_circuit("SimControl3", [q], [c])

# Add gates
# Encode state
sim_control3.cx(q[0], q[1]) 
sim_control3.cx(q[1], q[2]) 
# Error detection
sim_control3.cx(q[0], q[3]) 
sim_control3.cx(q[1], q[3]) 
sim_control3.cx(q[0], q[4]) 
sim_control3.cx(q[1], q[4]) 

# Add measurement operation
sim_control3.measure(q[3], c[3])
sim_control3.measure(q[4], c[4])

# Execute circuit
results = qp1.execute("SimControl3")

# Plot measurement results 
print("Measurement after simulation gate without errors (control):")
plot_histogram(results.get_counts("SimControl3"))
# Out:
# Measurement after simulation gate without errors (control):

# %%
# 3 qubits plus 2 ancillary qubits
n = 5

for val in [0, 1, 2]:
    # Run circuit to detect single bit flip error on quantum simulator
    qp2bit = QuantumProgram()
    
    # Quantum register
    q = qp2bit.create_quantum_register("q", n)
    # Classical register
    c = qp2bit.create_classical_register("c", n) 

    # SimControl3 circuit
    sim_err_bit3 = qp2bit.create_circuit("SimErrorBit3", [q], [c])

    # ADD GATES
    # Encode state
    sim_err_bit3.cx(q[0], q[1]) 
    sim_err_bit3.cx(q[0], q[2]) 
    # Introduce bit flip error
    sim_err_bit3.x(q[val])
    # Error detection
    sim_err_bit3.cx(q[0], q[3]) 
    sim_err_bit3.cx(q[1], q[3]) 
    sim_err_bit3.cx(q[0], q[4]) 
    sim_err_bit3.cx(q[2], q[4]) 

    # Add measurement operation
    sim_err_bit3.measure(q[3], c[3])
    sim_err_bit3.measure(q[4], c[4])

    # Execute circuit
    results = qp2bit.execute("SimErrorBit3")

    # Plot measurement results 
    print("Measurement after simulation gate with bit flip error on qubit", val, ":")
    plot_histogram(results.get_counts("SimErrorBit3"))
# Out:
# Measurement after simulation gate with bit flip error on qubit 0 :
# Measurement after simulation gate with bit flip error on qubit 1 :
# Measurement after simulation gate with bit flip error on qubit 2 :

# %%
# 3 qubits plus 2 ancillary qubits
n = 5

for val in [0, 1, 2]:
    # Run circuit to detect single phase flip error on quantum simulator
    qp2phase = QuantumProgram()

    # Quantum register
    q = qp2phase.create_quantum_register("q", n)
    # Classical register
    c = qp2phase.create_classical_register("c", n) 

    # SimControl3 circuit
    sim_err_phase3 = qp2phase.create_circuit("SimErrorPhase3", [q], [c])
    
    # ADD GATES
    # Encode state
    sim_err_phase3.cx(q[0], q[1]) 
    sim_err_phase3.cx(q[0], q[2])
    # Hadamard basis
    sim_err_phase3.h(q[0])
    sim_err_phase3.h(q[1])
    sim_err_phase3.h(q[2])
    # Introduce phase flip error
    sim_err_phase3.z(q[val])
    # Hadamard basis
    sim_err_phase3.h(q[0])
    sim_err_phase3.h(q[1])
    sim_err_phase3.h(q[2])
    # Error detection
    sim_err_phase3.cx(q[0], q[3]) 
    sim_err_phase3.cx(q[1], q[3]) 
    sim_err_phase3.cx(q[0], q[4]) 
    sim_err_phase3.cx(q[2], q[4]) 
    # Hadamard basis
    sim_err_phase3.h(q[0])
    sim_err_phase3.h(q[1])
    sim_err_phase3.h(q[2])

    # Add measurement operation
    sim_err_phase3.measure(q[3], c[3])
    sim_err_phase3.measure(q[4], c[4])

    # Execute circuit
    results = qp2phase.execute("SimErrorPhase3")

    # Plot measurement results 
    print("Measurement after simulation gate with phase flip error on qubit", val, ":")
    plot_histogram(results.get_counts("SimErrorPhase3"))
# Out:
# Measurement after simulation gate with phase flip error on qubit 0 :
# Measurement after simulation gate with phase flip error on qubit 1 :
# Measurement after simulation gate with phase flip error on qubit 2 :

# %%
# Run circuit without any errors on IBMQ backend
qp3 = QuantumProgram()

# 3 qubits plus 2 ancillary qubits
n = 5

# Quantum register
q = qp3.create_quantum_register("q", n)
# Classical register
c = qp3.create_classical_register("c", n) 

# SimControl3 circuit
imbq_control3 = qp3.create_circuit("IBMQControl3", [q], [c])

# Add gates
# Encode state
imbq_control3.cx(q[0], q[1]) 
imbq_control3.cx(q[1], q[2]) 
# Error detection
imbq_control3.cx(q[0], q[3]) 
imbq_control3.cx(q[1], q[3]) 
imbq_control3.cx(q[0], q[4]) 
imbq_control3.cx(q[1], q[4]) 

# Add measurement operation
imbq_control3.measure(q[3], c[3])
imbq_control3.measure(q[4], c[4])

# Set parameters
backend = 'ibmqx5'   
circuits = ['IBMQControl3']  
shots = 1024           
max_credits = 3          
wait = 10   
timeout = 2400 
result_real = qp3.execute(circuits, backend, shots=shots, max_credits=max_credits, wait=wait, timeout=timeout)
results_real.get_counts("IBMQControl3")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/qiskit/backends/_backendutils.py in configuration(backend_name)
#     263     try:
# --> 264         return _REGISTERED_BACKENDS[backend_name].configuration
#     265     except KeyError:
#
# KeyError: 'ibmqx5'
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-5-8c103433ba28> in <module>()
#      34 wait = 10
#      35 timeout = 240
# ---> 36 result_real = qp3.execute(circuits, backend, shots=shots, max_credits=max_credits, wait=wait, timeout=timeout)
#      37 results_real.get_counts("IBMQControl3")
#
# /anaconda/lib/python3.6/site-packages/qiskit/_quantumprogram.py in execute(self, name_of_circuits, backend, config, wait, timeout, basis_gates, coupling_map, initial_layout, shots, max_credits, seed, hpc)
#    1519                             coupling_map=coupling_map, initial_layout=initial_layout,
#    1520                             shots=shots, max_credits=max_credits, seed=seed,
# -> 1521                             hpc=hpc)
#    1522         result = self.run(qobj, wait=wait, timeout=timeout)
#    1523         return result
#
# /anaconda/lib/python3.6/site-packages/qiskit/_quantumprogram.py in compile(self, name_of_circuits, backend, config, basis_gates, coupling_map, initial_layout, shots, max_credits, seed, qobj_id, hpc)
#    1140
#    1141         qobj['circuits'] = []
# -> 1142         backend_conf = qiskit.backends.configuration(backend)
#    1143         if not basis_gates:
#    1144             if 'basis_gates' in backend_conf:
#
# /anaconda/lib/python3.6/site-packages/qiskit/backends/_backendutils.py in configuration(backend_name)
#     264         return _REGISTERED_BACKENDS[backend_name].configuration
#     265     except KeyError:
# --> 266         raise LookupError('backend "{}" is not available'.format(backend_name))
#     267
#     268
#
# LookupError: backend "ibmqx5" is not available

# %%
# Run circuit to detect bit flip error on IBMQ backend
qp4bit = QuantumProgram()

# 3 qubits plus 2 ancillary qubits
n = 5

# Quantum register
q = qp4bit.create_quantum_register("q", n)
# Classical register
c = qp4bit.create_classical_register("c", n) 

# SimControl3 circuit
imbq_err_bit3 = qp4bit.create_circuit("IMBQErrorBit3", [q], [c])

# ADD GATES
# Encode state
imbq_err_bit3.cx(q[0], q[1]) 
imbq_err_bit3.cx(q[1], q[2]) 
# Introduce bit flip error
imbq_err_bit3.x(q[0])
# Error detection
imbq_err_bit3.cx(q[0], q[3]) 
imbq_err_bit3.cx(q[1], q[3]) 
imbq_err_bit3.cx(q[0], q[4]) 
imbq_err_bit3.cx(q[1], q[4]) 

# Add measurement operation
imbq_err_bit3.measure(q[3], c[3])
imbq_err_bit3.measure(q[4], c[4])

# Set parameters
backend = 'ibmqx5'   
circuits = ['IMBQErrorBit3']  
shots = 1024           
max_credits = 3          
wait = 10   
timeout = 240 
result_real = qp4bit.execute(circuits, backend, shots=shots, max_credits=max_credits, wait=wait, timeout=timeout)
results_real.get_counts("IBMQErrr3")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/qiskit/backends/_backendutils.py in configuration(backend_name)
#     263     try:
# --> 264         return _REGISTERED_BACKENDS[backend_name].configuration
#     265     except KeyError:
#
# KeyError: 'ibmqx5'
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-43-0b87eddc23bc> in <module>()
#      36 wait = 10
#      37 timeout = 240
# ---> 38 result_real = qp4bit.execute(circuits, backend, shots=shots, max_credits=max_credits, wait=wait, timeout=timeout)
#      39 results_real.get_counts("IBMQErrorBit3")
#
# /anaconda3/lib/python3.6/site-packages/qiskit/_quantumprogram.py in execute(self, name_of_circuits, backend, config, wait, timeout, basis_gates, coupling_map, initial_layout, shots, max_credits, seed, hpc)
#    1519                             coupling_map=coupling_map, initial_layout=initial_layout,
#    1520                             shots=shots, max_credits=max_credits, seed=seed,
# -> 1521                             hpc=hpc)
#    1522         result = self.run(qobj, wait=wait, timeout=timeout)
#    1523         return result
#
# /anaconda3/lib/python3.6/site-packages/qiskit/_quantumprogram.py in compile(self, name_of_circuits, backend, config, basis_gates, coupling_map, initial_layout, shots, max_credits, seed, qobj_id, hpc)
#    1140
#    1141         qobj['circuits'] = []
# -> 1142         backend_conf = qiskit.backends.configuration(backend)
#    1143         if not basis_gates:
#    1144             if 'basis_gates' in backend_conf:
#
# /anaconda3/lib/python3.6/site-packages/qiskit/backends/_backendutils.py in configuration(backend_name)
#     264         return _REGISTERED_BACKENDS[backend_name].configuration
#     265     except KeyError:
# --> 266         raise LookupError('backend "{}" is not available'.format(backend_name))
#     267
#     268
#
# LookupError: backend "ibmqx5" is not available

# %%
# Run circuit to detect phase flip error on IBMQ backend
qp4phase = QuantumProgram()

# 3 qubits plus 2 ancillary qubits
n = 5

# Quantum register
q = qp4phase.create_quantum_register("q", n)
# Classical register
c = qp4phase.create_classical_register("c", n) 

# IBMQControl4 circuit
imbq_err_phase3 = qp4bit.create_circuit("IMBQPhaseBit3", [q], [c])

# ADD GATES
# Hadamard basis
imbq_err_phase3.h(q[0]) 
imbq_err_phase3.h(q[1]) 
imbq_err_phase3.h(q[2]) 
imbq_err_phase3.h(q[3]) 
imbq_err_phase3.h(q[4]) 
# Encode state
imbq_err_phase3.cx(q[0], q[1]) 
imbq_err_phase3.cx(q[1], q[2]) 
# Introduce bit flip error
imbq_err_phase3.z(q[0])
# Error detection
imbq_err_phase3.cx(q[0], q[3]) 
imbq_err_phase3.cx(q[1], q[3]) 
imbq_err_phase3.cx(q[0], q[4]) 
imbq_err_phase3.cx(q[1], q[4]) 
# Reverse Hadamard basis
imbq_err_phase3.h(q[0]) 
imbq_err_phase3.h(q[1]) 
imbq_err_phase3.h(q[2]) 
imbq_err_phase3.h(q[3]) 
imbq_err_phase3.h(q[4]) 

# Add measurement operation
imbq_err_phase3.measure(q[3], c[3])
imbq_err_phase3.measure(q[4], c[4])

# Set parameters
backend = 'ibmqx5'   
circuits = ['IMBQErrorPhase3']  
shots = 1024           
max_credits = 3          
wait = 10   
timeout = 240 
result_real = qp4phase.execute(circuits, backend, shots=shots, max_credits=max_credits, wait=wait, timeout=timeout)
results_real.get_counts("IBMQErrorPhase3")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/qiskit/backends/_backendutils.py in configuration(backend_name)
#     263     try:
# --> 264         return _REGISTERED_BACKENDS[backend_name].configuration
#     265     except KeyError:
#
# KeyError: 'ibmqx5'
#
# During handling of the above exception, another exception occurred:
#
# LookupError                               Traceback (most recent call last)
# <ipython-input-42-824be50f3f19> in <module>()
#      48 wait = 10
#      49 timeout = 240
# ---> 50 result_real = qp4phase.execute(circuits, backend, shots=shots, max_credits=max_credits, wait=wait, timeout=timeout)
#      51 results_real.get_counts("IBMQErrorPhase3")
#
# /anaconda3/lib/python3.6/site-packages/qiskit/_quantumprogram.py in execute(self, name_of_circuits, backend, config, wait, timeout, basis_gates, coupling_map, initial_layout, shots, max_credits, seed, hpc)
#    1519                             coupling_map=coupling_map, initial_layout=initial_layout,
#    1520                             shots=shots, max_credits=max_credits, seed=seed,
# -> 1521                             hpc=hpc)
#    1522         result = self.run(qobj, wait=wait, timeout=timeout)
#    1523         return result
#
# /anaconda3/lib/python3.6/site-packages/qiskit/_quantumprogram.py in compile(self, name_of_circuits, backend, config, basis_gates, coupling_map, initial_layout, shots, max_credits, seed, qobj_id, hpc)
#    1140
#    1141         qobj['circuits'] = []
# -> 1142         backend_conf = qiskit.backends.configuration(backend)
#    1143         if not basis_gates:
#    1144             if 'basis_gates' in backend_conf:
#
# /anaconda3/lib/python3.6/site-packages/qiskit/backends/_backendutils.py in configuration(backend_name)
#     264         return _REGISTERED_BACKENDS[backend_name].configuration
#     265     except KeyError:
# --> 266         raise LookupError('backend "{}" is not available'.format(backend_name))
#     267
#     268
#
# LookupError: backend "ibmqx5" is not available
